# %% [markdown]
# # STEP 2: AppEEARS API
#
# # STEP 0: Set up
#
# To get started on this notebook, you’ll need to restore any variables
# from previous notebooks to your workspace. To save time and memory, make
# sure to specify which variables you want to load.

# %%
# %store -r

# %% [markdown]
# You will also need to import any libraries you are using in this
# notebook, since they won’t carry over from the previous notebook:

# %%
id = 'stars'
site_name = 'Gila River Indian Community'
data_dir = 'gila-river'
download_key = 'gila-river-ndvi'
project_title = 'Gila River Vegetation'
project.project_dir = '/workspaces/data/gila-river-vegetation/gila-river'

# %%
# Import python libraries
#import json
import os
import pathlib
from glob import glob

import earthpy.api.appeears as eaapp
import earthpy
import geopandas as gpd
import hvplot.pandas
import hvplot.xarray
import pandas as pd
import rioxarray as rxr
import xarray as xr
import holoviews as hv
import matplotlib.pyplot as plt
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1011'>
#   <div id="a39b07a0-acf0-41f5-a261-d62607ae51cf" data-root-id="p1011" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"f1e0c8bb-9d38-4ee7-8a65-fa214054950d":{"version":"3.8.0","title":"Bokeh Application","config":{"type":"object","name":"DocumentConfig","id":"p1009","attributes":{"notifications":{"type":"object","name":"Notifications","id":"p1010"}}},"roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1011"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1012","attributes":{"plot_id":"p1011","comm_id":"10f93591c2774376a5bd67ea90e1a78d","client_comm_id":"efb9d5d5481640b6b6c525311af2d62f"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"start","kind":"Any","default":0},{"name":"end","kind":"Any","default":100},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"ReactComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"AnyWidgetComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_rendered","kind":"Any","default":false},{"name":"_destroyed","kind":"Any","default":false}]},{"typ ...
#   var render_items = [{"docid":"f1e0c8bb-9d38-4ee7-8a65-fa214054950d","roots":{"p1011":"a39b07a0-acf0-41f5-a261-d62607ae51cf"},"root_ids":["p1011"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %% [markdown]
# ## Exploring the AppEEARS API for NASA Earthdata access
#
# Before you get started with the data download today, you will need a
# free [NASA Earthdata account](https://urs.earthdata.nasa.gov/home) if
# you don’t have one already!
#
# Over the next four cells, you will download MODIS NDVI data for the
# study period. MODIS is a multispectral instrument that measures Red and
# NIR data (and so can be used for NDVI). There are two MODIS sensors on
# two different platforms: satellites Terra and Aqua.
#
# <link rel="stylesheet" type="text/css" href="./assets/styles.css"><div class="callout callout-style-default callout-titled callout-read"><div class="callout-header"><div class="callout-icon-container"><i class="callout-icon"></i></div><div class="callout-title-container flex-fill">Read More</div></div><div class="callout-body-container callout-body"><p><a href="https://modis.gsfc.nasa.gov/">Learn more about MODIS
# datasets and the science they support</a></p></div></div>
#
# Since we’re asking for a special download that only covers our study
# area, we can’t just find a link to the data - we have to negotiate with
# the data server. We’re doing this using the
# [APPEEARS](https://appeears.earthdatacloud.nasa.gov/api/) API
# (Application Programming Interface). The API makes it possible for you
# to request data using code. You can use code from the `earthpy` library
# to handle the API request.
#
# <link rel="stylesheet" type="text/css" href="./assets/styles.css"><div class="callout callout-style-default callout-titled callout-task"><div class="callout-header"><div class="callout-icon-container"><i class="callout-icon"></i></div><div class="callout-title-container flex-fill">Try It</div></div><div class="callout-body-container callout-body"><p>Often when we want to do something more complex in coding we find an
# example and modify it. This download code is already almost a working
# example. Your task will be:</p>
# <ol type="1">
# <li>Replace the start and end dates in the task parameters. Download
# data from July, when greenery is at its peak in the Northern
# Hemisphere.</li>
# <li>Replace the year range. You should get 3 years before and after the
# event so you can see the change!</li>
# <li>Replace <code>gdf</code> with the name of <strong>your</strong> site
# geodataframe.</li>
# <li><strong>Enter your NASA Earthdata username and password when
# prompted.</strong> The prompts can be a little hard to see – look at the
# top of your screen!</li>
# </ol></div></div>
#
# <link rel="stylesheet" type="text/css" href="./assets/styles.css"><div class="callout callout-style-default callout-titled callout-respond"><div class="callout-header"><div class="callout-icon-container"><i class="callout-icon"></i></div><div class="callout-title-container flex-fill">Reflect and Respond</div></div><div class="callout-body-container callout-body"><p>What would the product and layer name be if you were trying to
# download Landsat Surface Temperature Analysis Ready Data (ARD) instead
# of MODIS NDVI?</p></div></div>
#
# > **Important**
# >
# > It can take some time for Appeears to process your request - anything
# > from a few minutes to a few hours depending on how busy they are. You
# > can check your progress by:
# >
# > 1.  Going to the [Appeears
# >     webpage](https://appeears.earthdatacloud.nasa.gov/)
# > 2.  Clicking the `Explore` tab
# > 3.  Logging in with your Earthdata account

# %%
project = earthpy.Project(
    "Gila River Vegetation",
    dirname="gila-river-vegetation"
)

# %%
# Initialize AppeearsDownloader for MODIS NDVI data
ndvi_downloader = eaapp.AppeearsDownloader(
    download_key='gila-river',
    project=project,
    product='MOD13Q1.061',
    layer='_250m_16_days_NDVI',
    start_date="06-01",
    end_date="09-01",
    recurring=True,
    year_range=[2015, 2025],
    polygon=gila_boundary
)

# %%
# Download the prepared download -- this can take some time!
ndvi_downloader.download_files(cache=False)

# %%
# Open the GeoTIFF
tif_path = "/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2015145000000_aid0001.tif"

raster = rxr.open_rasterio(tif_path)

# Plot
raster.plot(cmap='PiYG')

plt.show()

# %%
# Open the GeoTIFF
tif_path = "/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2022193000000_aid0001.tif"

raster = rxr.open_rasterio(tif_path)

# Plot
raster.plot(cmap="PiYG")

plt.show()

# %% [markdown]
# ## Putting it together: Working with multi-file raster datasets in Python
#
# Now you need to load all the downloaded files into Python. You may have
# noticed that the \`earthpy.appears module gives us all the downloaded
# file names…but only some of those are the NDVI files we want while
# others are quality files that tell us about the confidence in the
# dataset. For now, the files we want all have “NDVI” in the name.
#
# Let’s start by getting all the NDVI file names. You will also need to
# extract the date from the filename. Check out [the lesson on getting
# information from filenames in the
# textbook](https://www.earthdatascience.org/courses/intro-to-earth-data-science/write-efficient-python-code/loops/data-workflows-with-loops/).
#
# > **GOTCHA ALERT!**
# >
# > `glob` doesn’t necessarily find files in the order you would expect.
# > Make sure to **sort** your file names like it says in the textbook.

# %%
project.project_dir
# Out:
# '/workspaces/data/gila-river-vegetation/gila-river'

# %%
# Get list of NDVI tif file paths
ndvi_paths = sorted(glob(os.path.join(
    '/workspaces/data/gila-river-vegetation/gila-river', '**', '*NDVI*.tif')))
f'{len(ndvi_paths)} NDVI paths found'
# Out:
# '77 NDVI paths found'

# %%
ndvi_paths
# Out:
# ['/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2015145000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2015161000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2015177000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2015193000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2015209000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2015225000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2015241000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2016145000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2016161000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2016177000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2016193000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2016209000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2016225000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2016241000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2017145000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2017161000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2017177000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2017193000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2017209000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2017225000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2017241000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2018145000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2018161000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2018177000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2018193000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2018209000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2018225000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2018241000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2019145000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2019161000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2019177000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2019193000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2019209000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2019225000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2019241000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2020145000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2020161000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2020177000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2020193000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2020209000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2020225000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2020241000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2021145000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2021161000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2021177000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2021193000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2021209000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2021225000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2021241000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2022145000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2022161000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2022177000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2022193000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2022209000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2022225000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2022241000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2023145000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2023161000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2023177000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2023193000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2023209000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2023225000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2023241000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2024145000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2024161000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2024177000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2024193000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2024209000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2024225000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2024241000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2025145000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2025161000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2025177000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2025193000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2025209000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2025225000000_aid0001.tif',
#  '/workspaces/data/gila-river-vegetation/gila-river/MOD13Q1.061_2015137_to_2025244/MOD13Q1.061__250m_16_days_NDVI_doy2025241000000_aid0001.tif']

# %% [markdown]
# ### Repeating tasks in Python
#
# Now you should have a few dozen files! For each file, you need to:
#
# -   Load the file in using the `rioxarray` library
# -   Get the date from the file name
# -   Add the date as a dimension coordinate
# -   Give your data variable a name
#
# You don’t want to write out the code for each file! That’s a recipe for
# **copy pasta** and errors. Luckily, Python has tools for doing similar
# tasks repeatedly. In this case, you’ll use one called a `for` loop.
#
# There’s some code below that uses a `for` loop in what is called an
# **accumulation pattern** to process each file. That means that you will
# save the results of your processing to a list each time you process the
# files, and then merge all the arrays in the list.
#
# <link rel="stylesheet" type="text/css" href="./assets/styles.css"><div class="callout callout-style-default callout-titled callout-task"><div class="callout-header"><div class="callout-icon-container"><i class="callout-icon"></i></div><div class="callout-title-container flex-fill">Try It</div></div><div class="callout-body-container callout-body"><ul>
# <li>Look at the file names. How many characters from the end is the
# date? <code>doy_start</code> and <code>doy_end</code> are used to
# extract the day of the year (doy) from the file name. You will need to
# count characters from the end and change the values to get the right
# part of the file name. HINT: the index -1 in Python means the last
# value, -2 second-to-last, and so on.</li>
# <li>Replace any required variable names with your chosen variable
# names</li>
# </ul></div></div>

# %%
from pathlib import Path

doy_start = -25
doy_end = -19

# Loop through each NDVI image
ndvi_das_dl = []
for ndvi_path in ndvi_paths:
    ndvi_path = Path(ndvi_path)

    # Get date from file name
    doy = ndvi_path.name[doy_start:doy_end]
    date = pd.to_datetime(doy, format='%Y%j')

    # Open dataset
    da = rxr.open_rasterio(ndvi_path, mask_and_scale=True).squeeze()

    # Add date dimension and clean up metadata
    da = da.assign_coords({'date': date})
    da = da.expand_dims({'date': 1})
    da.name = 'NDVI'

    # Prepare for concatenation
    ndvi_das_dl.append(da)

len(ndvi_das_dl)
# Out:
# 77

# %%
ndvi_das_dl
# Out:
# [<xarray.DataArray 'NDVI' (date: 1, y: 203, x: 381)> Size: 309kB
#  array([[[0.52459997, 0.4913    , 0.4845    , ..., 0.16059999,
#           0.16059999, 0.1805    ],
#          [0.6328    , 0.3384    , 0.2566    , ..., 0.1717    ,
#           0.1717    , 0.1521    ],
#          [0.3597    , 0.3821    , 0.38509998, ..., 0.1327    ,
#           0.0687    , 0.0687    ],
#          ...,
#          [0.1274    , 0.12289999, 0.1284    , ..., 0.15609999,
#           0.15609999, 0.1575    ],
#          [0.1232    , 0.12289999, 0.1296    , ..., 0.16929999,
#           0.16929999, 0.1944    ],
#          [0.12529999, 0.1208    , 0.1294    , ..., 0.188     ,
#           0.19669999, 0.23609999]]], shape=(1, 203, 381), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2015-01-14
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 381)> Size: 309kB
#  array([[[0.6236    , 0.4658    , 0.4669    , ..., 0.16849999,
#           0.16849999, 0.16759999],
#          [0.5652    , 0.3121    , 0.2514    , ..., 0.15969999,
#           0.15969999, 0.15799999],
#          [0.34809998, 0.43039998, 0.2514    , ..., 0.1445    ,
#           0.099     , 0.099     ],
#          ...,
#          [0.12249999, 0.1256    , 0.1268    , ..., 0.16499999,
#           0.16499999, 0.17379999],
#          [0.1178    , 0.1239    , 0.1274    , ..., 0.1802    ,
#           0.1802    , 0.22829999],
#          [0.1231    , 0.12069999, 0.1293    , ..., 0.2006    ,
#           0.1858    , 0.2261    ]]], shape=(1, 203, 381), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2015-01-16
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 381)> Size: 309kB
#  array([[[0.51      , 0.51      , 0.53249997, ..., 0.1528    ,
#           0.1528    , 0.15709999],
#          [0.3813    , 0.3218    , 0.53249997, ..., 0.1471    ,
#           0.1471    , 0.1471    ],
#          [0.3813    , 0.36249998, 0.3575    , ..., 0.1501    ,
#           0.0832    , 0.061     ],
#          ...,
#          [0.12789999, 0.12789999, 0.1283    , ..., 0.1651    ,
#           0.1651    , 0.1651    ],
#          [0.1243    , 0.1275    , 0.1283    , ..., 0.21429999,
#           0.21429999, 0.20549999],
#          [0.1243    , 0.1275    , 0.12969999, ..., 0.18969999,
#           0.21429999, 0.21429999]]], shape=(1, 203, 381), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2015-01-17
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 381)> Size: 309kB
#  array([[[0.5557    , 0.5652    , 0.6292    , ..., 0.1672    ,
#           0.1672    , 0.1609    ],
#          [0.4806    , 0.30519998, 0.2677    , ..., 0.14899999,
#           0.14899999, 0.12029999],
#          [0.3328    , 0.36429998, 0.3658    , ..., 0.1408    ,
#           0.055     , 0.055     ],
#          ...,
#          [0.12539999, 0.1195    , 0.1183    , ..., 0.1513    ,
#           0.1513    , 0.1608    ],
#          [0.1173    , 0.1173    , 0.1228    , ..., 0.1777    ,
#           0.1777    , 0.20349999],
#          [0.1206    , 0.1252    , 0.1228    , ..., 0.1774    ,
#           0.2094    , 0.217     ]]], shape=(1, 203, 381), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2015-01-19
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 381)> Size: 309kB
#  array([[[0.5511    , 0.5652    , 0.643     , ..., 0.1575    ,
#           0.1575    , 0.1648    ],
#          [0.48819998, 0.3664    , 0.32209998, ..., 0.1582    ,
#           0.1582    , 0.1583    ],
#          [0.3967    , 0.4655    , 0.341     , ..., 0.1525    ,
#           0.08109999, 0.08109999],
#          ...,
#          [0.12329999, 0.1175    , 0.125     , ..., 0.17889999,
#           0.17889999, 0.19829999],
#          [0.12159999, 0.11499999, 0.1234    , ..., 0.18439999,
#           0.18439999, 0.1894    ],
#          [0.12159999, 0.112     , 0.1234    , ..., 0.2233    ,
#           0.21419999, 0.2473    ]]], shape=(1, 203, 381), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2015-01-20
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 381)> Size: 309kB
#  array([[[0.515     , 0.4032    , 0.574     , ..., 0.1683    ,
#           0.1683    , 0.1708    ],
#          [0.6638    , 0.41779998, 0.3288    , ..., 0.1312    ,
#           0.1312    , 0.1312    ],
#          [0.3364    , 0.4123    , 0.4233    , ..., 0.1295    ,
#           0.1295    , 0.1195    ],
#          ...,
#          [0.11809999, 0.118     , 0.1174    , ..., 0.1704    ,
#           0.1704    , 0.1564    ],
#          [0.11499999, 0.11449999, 0.12      , ..., 0.21329999,
#           0.21329999, 0.2455    ],
#          [0.12069999, 0.11499999, 0.1193    , ..., 0.1865    ,
#           0.21329999, 0.21429999]]], shape=(1, 203, 381), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2015-01-22
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 381)> Size: 309kB
#  array([[[0.5063    , 0.5962    , 0.7529    , ..., 0.17099999,
#           0.17099999, 0.1575    ],
#          [0.56619996, 0.3231    , 0.3292    , ..., 0.17099999,
#           0.17099999, 0.1575    ],
#          [0.3479    , 0.3827    , 0.4067    , ..., 0.1674    ,
#           0.10349999, 0.10349999],
#          ...,
#          [0.1196    , 0.11629999, 0.12629999, ..., 0.1769    ,
#           0.1769    , 0.1584    ],
#          [0.1174    , 0.1113    , 0.12629999, ..., 0.24589999,
#           0.24589999, 0.18879999],
#          [0.1214    , 0.1234    , 0.1236    , ..., 0.1988    ,
#           0.24589999, 0.23519999]]], shape=(1, 203, 381), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2015-01-24
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 381)> Size: 309kB
#  array([[[0.42769998, 0.49089998, 0.5001    , ..., 0.13589999,
#           0.13589999, 0.1479    ],
#          [0.2499    , 0.2697    , 0.49089998, ..., 0.14479999,
#           0.14479999, 0.1453    ],
#          [0.33499998, 0.3951    , 0.3786    , ..., 0.1413    ,
#           0.0835    , 0.077     ],
#          ...,
#          [0.10749999, 0.1047    , 0.11589999, ..., 0.14819999,
#           0.14819999, 0.1565    ],
#          [0.0993    , 0.1047    , 0.11589999, ..., 0.2172    ,
#           0.2172    , 0.2087    ],
#          [0.1004    , 0.1071    , 0.1139    , ..., 0.1572    ,
#           0.17      , 0.2172    ]]], shape=(1, 203, 381), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2016-01-14
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 381)> Size: 309kB
#  array([[[0.4856    , 0.5198    , 0.5358    , ..., 0.13509999,
#           0.13509999, 0.1372    ],
#          [0.5559    , 0.3166    , 0.2689    , ..., 0.1382    ,
#           0.1382    , 0.1382    ],
#          [0.3012    , 0.3631    , 0.4077    , ..., 0.1317    ,
#           0.0802    , 0.0902    ],
#          ...,
#          [0.1125    , 0.1068    , 0.1108    , ..., 0.1546    ,
#           0.1546    , 0.14729999],
#          [0.1013    , 0.10309999, 0.109     , ..., 0.1978    ,
#           0.1978    , 0.18699999],
#          [0.1082    , 0.10309999, 0.109     , ..., 0.14209999,
#           0.2171    , 0.1862    ]]], shape=(1, 203, 381), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2016-01-16
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 381)> Size: 309kB
#  array([[[0.3297    , 0.4296    , 0.40089998, ..., 0.132     ,
#           0.132     , 0.132     ],
#          [0.3646    , 0.2942    , 0.24499999, ..., 0.1314    ,
#           0.1314    , 0.1201    ],
#          [0.32119998, 0.3841    , 0.38459998, ..., 0.1513    ,
#           0.0883    , 0.058     ],
#          ...,
#          [0.10089999, 0.10179999, 0.11059999, ..., 0.1503    ,
#           0.1503    , 0.1656    ],
#          [0.0992    , 0.10179999, 0.1064    , ..., 0.21249999,
#           0.21249999, 0.1995    ],
#          [0.0992    , 0.09959999, 0.1051    , ..., 0.146     ,
#           0.2329    , 0.1979    ]]], shape=(1, 203, 381), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2016-01-17
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 381)> Size: 309kB
#  array([[[0.539     , 0.45189998, 0.52529997, ..., 0.162     ,
#           0.162     , 0.1557    ],
#          [0.6107    , 0.39729998, 0.3342    , ..., 0.162     ,
#           0.162     , 0.1557    ],
#          [0.33789998, 0.4052    , 0.3721    , ..., 0.1432    ,
#           0.0746    , 0.0746    ],
#          ...,
#          [0.1052    , 0.1036    , 0.1113    , ..., 0.1739    ,
#           0.1739    , 0.15609999],
#          [0.10089999, 0.1027    , 0.1104    , ..., 0.1739    ,
#           0.1739    , 0.2225    ],
#          [0.1068    , 0.102     , 0.1104    , ..., 0.1319    ,
#           0.2128    , 0.2523    ]]], shape=(1, 203, 381), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2016-01-19
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 381)> Size: 309kB
#  array([[[0.3933    , 0.3838    , 0.3719    , ..., 0.1559    ,
#           0.1559    , 0.13319999],
#          [0.4411    , 0.33679998, 0.2731    , ..., 0.125     ,
#           0.125     , 0.17799999],
#          [0.3296    , 0.3626    , 0.4154    , ..., 0.1463    ,
#           0.09339999, 0.12289999],
#          ...,
#          [0.10399999, 0.1049    , 0.1058    , ..., 0.1577    ,
#           0.1577    , 0.1656    ],
#          [0.1028    , 0.10439999, 0.1049    , ..., 0.24849999,
#           0.24849999, 0.19669999],
#          [0.1024    , 0.0992    , 0.1072    , ..., 0.1794    ,
#           0.2214    , 0.24849999]]], shape=(1, 203, 381), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2016-01-20
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 381)> Size: 309kB
#  array([[[0.61329997, 0.48049998, 0.4445    , ..., 0.1619    ,
#           0.1619    , 0.1629    ],
#          [0.53529996, 0.48049998, 0.44259998, ..., 0.1329    ,
#           0.1329    , 0.1032    ],
#          [0.39159998, 0.305     , 0.333     , ..., 0.1052    ,
#           0.1311    , 0.0911    ],
#          ...,
#          [0.1061    , 0.10439999, 0.1056    , ..., 0.1529    ,
#           0.1529    , 0.1582    ],
#          [0.1033    , 0.0999    , 0.10569999, ..., 0.2192    ,
#           0.2192    , 0.2137    ],
#          [0.1007    , 0.1024    , 0.1089    , ..., 0.15699999,
#           0.2148    , 0.242     ]]], shape=(1, 203, 381), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2016-01-22
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 381)> Size: 309kB
#  array([[[0.3885    , 0.3885    , 0.42209998, ..., 0.1673    ,
#           0.1673    , 0.1542    ],
#          [0.27969998, 0.2554    , 0.35819998, ..., 0.16239999,
#           0.16239999, 0.15079999],
#          [0.35529998, 0.43539998, 0.39609998, ..., 0.19659999,
#           0.11279999, 0.0717    ],
#          ...,
#          [0.1055    , 0.1028    , 0.1059    , ..., 0.1617    ,
#           0.1617    , 0.16499999],
#          [0.1008    , 0.1047    , 0.10349999, ..., 0.2316    ,
#           0.2316    , 0.2384    ],
#          [0.107     , 0.1046    , 0.1047    , ..., 0.159     ,
#           0.2109    , 0.2129    ]]], shape=(1, 203, 381), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2016-01-24
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 381)> Size: 309kB
#  array([[[0.6522    , 0.42499998, 0.5787    , ..., 0.1458    ,
#           0.1458    , 0.15259999],
#          [0.6522    , 0.43919998, 0.40539998, ..., 0.1567    ,
#           0.1567    , 0.1338    ],
#          [0.3445    , 0.3242    , 0.3522    , ..., 0.1208    ,
#           0.1208    , 0.0676    ],
#          ...,
#          [0.1112    , 0.1078    , 0.1095    , ..., 0.141     ,
#           0.141     , 0.153     ],
#          [0.1103    , 0.1051    , 0.1114    , ..., 0.20719999,
#           0.20719999, 0.18519999],
#          [0.1073    , 0.1049    , 0.1138    , ..., 0.1422    ,
#           0.20889999, 0.1828    ]]], shape=(1, 203, 381), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2017-01-14
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 381)> Size: 309kB
#  array([[[0.3606    , 0.3876    , 0.5646    , ..., 0.1551    ,
#           0.1551    , 0.1551    ],
#          [0.2651    , 0.3876    , 0.49319997, ..., 0.1463    ,
#           0.1463    , 0.1197    ],
#          [0.35909998, 0.3446    , 0.35029998, ..., 0.0997    ,
#           0.0997    , 0.0519    ],
#          ...,
#          [0.1121    , 0.1091    , 0.1135    , ..., 0.1528    ,
#           0.1528    , 0.1522    ],
#          [0.1064    , 0.1209    , 0.119     , ..., 0.21319999,
#           0.21319999, 0.18969999],
#          [0.11099999, 0.1114    , 0.12029999, ..., 0.1457    ,
#           0.2131    , 0.18949999]]], shape=(1, 203, 381), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2017-01-16
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 381)> Size: 309kB
#  array([[[0.5291    , 0.4624    , 0.486     , ..., 0.1413    ,
#           0.1413    , 0.1633    ],
#          [0.5252    , 0.33949998, 0.2724    , ..., 0.1413    ,
#           0.1413    , 0.1327    ],
#          [0.3663    , 0.4517    , 0.43649998, ..., 0.15359999,
#           0.0749    , 0.0731    ],
#          ...,
#          [0.1111    , 0.1076    , 0.112     , ..., 0.1618    ,
#           0.1618    , 0.15359999],
#          [0.10969999, 0.1063    , 0.1142    , ..., 0.2471    ,
#           0.2471    , 0.2078    ],
#          [0.11149999, 0.11279999, 0.1156    , ..., 0.1715    ,
#           0.2471    , 0.21      ]]], shape=(1, 203, 381), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2017-01-17
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 381)> Size: 309kB
#  array([[[0.3139    , 0.3937    , 0.5988    , ..., 0.1513    ,
#           0.1513    , 0.1488    ],
#          [0.33069998, 0.3085    , 0.29799998, ..., 0.14649999,
#           0.14649999, 0.1248    ],
#          [0.3146    , 0.4211    , 0.4389    , ..., 0.1222    ,
#           0.1222    , 0.0478    ],
#          ...,
#          [0.11849999, 0.11849999, 0.113     , ..., 0.1481    ,
#           0.1481    , 0.1609    ],
#          [0.1056    , 0.09649999, 0.1103    , ..., 0.21859999,
#           0.21859999, 0.2145    ],
#          [0.10529999, 0.10529999, 0.1103    , ..., 0.1653    ,
#           0.22729999, 0.1915    ]]], shape=(1, 203, 381), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2017-01-19
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 381)> Size: 309kB
#  array([[[0.6046    , 0.4998    , 0.6522    , ..., 0.1759    ,
#           0.1759    , 0.17549999],
#          [0.4055    , 0.4908    , 0.4676    , ..., 0.15609999,
#           0.15609999, 0.1413    ],
#          [0.4281    , 0.484     , 0.484     , ..., 0.1184    ,
#           0.1184    , 0.033     ],
#          ...,
#          [0.1138    , 0.1116    , 0.1116    , ..., 0.1686    ,
#           0.1686    , 0.16059999],
#          [0.1078    , 0.1102    , 0.11189999, ..., 0.19749999,
#           0.19749999, 0.18969999],
#          [0.1108    , 0.10969999, 0.1148    , ..., 0.16229999,
#           0.233     , 0.23869999]]], shape=(1, 203, 381), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2017-01-20
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 381)> Size: 309kB
#  array([[[0.3972    , 0.4308    , 0.6211    , ..., 0.1979    ,
#           0.1979    , 0.1718    ],
#          [0.3791    , 0.3163    , 0.3278    , ..., 0.1169    ,
#           0.1169    , 0.1672    ],
#          [0.3924    , 0.4599    , 0.42819998, ..., 0.16589999,
#           0.16589999, 0.0669    ],
#          ...,
#          [0.11629999, 0.1125    , 0.1255    , ..., 0.1779    ,
#           0.1779    , 0.1853    ],
#          [0.11189999, 0.1127    , 0.12469999, ..., 0.2521    ,
#           0.2521    , 0.23869999],
#          [0.12029999, 0.1117    , 0.1243    , ..., 0.19029999,
#           0.21159999, 0.2303    ]]], shape=(1, 203, 381), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2017-01-22
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 381)> Size: 309kB
#  array([[[0.4877    , 0.4323    , 0.6091    , ..., 0.17029999,
#           0.17029999, 0.1721    ],
#          [0.4877    , 0.4242    , 0.463     , ..., 0.1757    ,
#           0.1757    , 0.1757    ],
#          [0.3206    , 0.3628    , 0.4055    , ..., 0.1855    ,
#           0.1011    , 0.12249999],
#          ...,
#          [0.1215    , 0.12069999, 0.1232    , ..., 0.16939999,
#           0.16939999, 0.1838    ],
#          [0.119     , 0.1212    , 0.1212    , ..., 0.2206    ,
#           0.2206    , 0.2342    ],
#          [0.1201    , 0.1212    , 0.1212    , ..., 0.20709999,
#           0.2796    , 0.251     ]]], shape=(1, 203, 381), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2017-01-24
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 381)> Size: 309kB
#  array([[[0.62839997, 0.41419998, 0.5742    , ..., 0.1264    ,
#           0.1264    , 0.1264    ],
#          [0.45679998, 0.4394    , 0.4122    , ..., 0.0991    ,
#           0.0991    , 0.1264    ],
#          [0.2873    , 0.3667    , 0.34489998, ..., 0.1357    ,
#           0.0991    , 0.0991    ],
#          ...,
#          [0.1007    , 0.09649999, 0.1014    , ..., 0.1444    ,
#           0.1444    , 0.1406    ],
#          [0.0967    , 0.1016    , 0.1016    , ..., 0.1591    ,
#           0.1591    , 0.1836    ],
#          [0.0948    , 0.0999    , 0.1016    , ..., 0.1419    ,
#           0.1973    , 0.16929999]]], shape=(1, 203, 381), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2018-01-14
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 381)> Size: 309kB
#  array([[[0.66889995, 0.4159    , 0.5011    , ..., 0.1449    ,
#           0.1449    , 0.1449    ],
#          [0.4623    , 0.4075    , 0.352     , ..., 0.1192    ,
#           0.1192    , 0.084     ],
#          [0.3771    , 0.42279997, 0.3999    , ..., 0.0984    ,
#           0.0984    , 0.084     ],
#          ...,
#          [0.1072    , 0.0931    , 0.098     , ..., 0.14119999,
#           0.14119999, 0.14649999],
#          [0.0874    , 0.0961    , 0.1023    , ..., 0.1933    ,
#           0.1933    , 0.1801    ],
#          [0.0896    , 0.0942    , 0.103     , ..., 0.14289999,
#           0.20289999, 0.17289999]]], shape=(1, 203, 381), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2018-01-16
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 381)> Size: 309kB
#  array([[[0.5794    , 0.4491    , 0.5536    , ..., 0.1408    ,
#           0.1408    , 0.1435    ],
#          [0.5664    , 0.28849998, 0.2519    , ..., 0.1219    ,
#           0.1219    , 0.1158    ],
#          [0.42409998, 0.3533    , 0.3712    , ..., 0.1131    ,
#           0.0835    , 0.1158    ],
#          ...,
#          [0.09339999, 0.0931    , 0.1024    , ..., 0.1427    ,
#           0.1427    , 0.14389999],
#          [0.09339999, 0.094     , 0.1024    , ..., 0.16499999,
#           0.16499999, 0.20969999],
#          [0.1096    , 0.094     , 0.11      , ..., 0.1796    ,
#           0.17999999, 0.20969999]]], shape=(1, 203, 381), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2018-01-17
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 381)> Size: 309kB
#  array([[[0.18769999, 0.4576    , 0.5286    , ..., 0.1406    ,
#           0.1406    , 0.1406    ],
#          [0.2531    , 0.31509998, 0.3698    , ..., 0.1406    ,
#           0.1406    , 0.1406    ],
#          [0.3983    , 0.2531    , 0.32529998, ..., 0.11669999,
#           0.11669999, 0.06439999],
#          ...,
#          [0.1091    , 0.1065    , 0.1108    , ..., 0.1634    ,
#           0.1634    , 0.1648    ],
#          [0.1116    , 0.108     , 0.108     , ..., 0.22659999,
#           0.22659999, 0.1648    ],
#          [0.1002    , 0.1148    , 0.108     , ..., 0.1818    ,
#           0.20989999, 0.22659999]]], shape=(1, 203, 381), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2018-01-19
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 381)> Size: 309kB
#  array([[[0.2749    , 0.42159998, 0.5025    , ..., 0.1466    ,
#           0.1466    , 0.1466    ],
#          [0.23879999, 0.2668    , 0.23879999, ..., 0.116     ,
#           0.116     , 0.116     ],
#          [0.357     , 0.4296    , 0.37719998, ..., 0.1414    ,
#           0.116     , 0.116     ],
#          ...,
#          [0.1045    , 0.1029    , 0.1048    , ..., 0.146     ,
#           0.146     , 0.14729999],
#          [0.1014    , 0.1029    , 0.1142    , ..., 0.1565    ,
#           0.1565    , 0.21149999],
#          [0.101     , 0.1006    , 0.1117    , ..., 0.1116    ,
#           0.1871    , 0.2058    ]]], shape=(1, 203, 381), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2018-01-20
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 381)> Size: 309kB
#  array([[[0.449     , 0.44059998, 0.6164    , ..., 0.1334    ,
#           0.1334    , 0.156     ],
#          [0.3838    , 0.3506    , 0.4359    , ..., 0.15089999,
#           0.15089999, 0.1334    ],
#          [0.3841    , 0.2854    , 0.36389998, ..., 0.1156    ,
#           0.08989999, 0.08989999],
#          ...,
#          [0.11369999, 0.11059999, 0.1201    , ..., 0.1514    ,
#           0.1514    , 0.1361    ],
#          [0.1184    , 0.1107    , 0.1168    , ..., 0.1568    ,
#           0.1568    , 0.20179999],
#          [0.1125    , 0.1107    , 0.1168    , ..., 0.18419999,
#           0.18079999, 0.22299999]]], shape=(1, 203, 381), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2018-01-22
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 381)> Size: 309kB
#  array([[[0.6304    , 0.442     , 0.4899    , ..., 0.17899999,
#           0.17899999, 0.1592    ],
#          [0.4296    , 0.4296    , 0.3773    , ..., 0.1771    ,
#           0.1771    , 0.12029999],
#          [0.3552    , 0.43109998, 0.43109998, ..., 0.1468    ,
#           0.0726    , 0.12029999],
#          ...,
#          [0.1073    , 0.1086    , 0.1131    , ..., 0.1407    ,
#           0.1407    , 0.1419    ],
#          [0.1019    , 0.1089    , 0.112     , ..., 0.169     ,
#           0.169     , 0.19929999],
#          [0.099     , 0.1091    , 0.1099    , ..., 0.1556    ,
#           0.1892    , 0.1846    ]]], shape=(1, 203, 381), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2018-01-24
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 381)> Size: 309kB
#  array([[[0.6109    , 0.40559998, 0.49469998, ..., 0.1717    ,
#           0.1717    , 0.184     ],
#          [0.5937    , 0.398     , 0.2626    , ..., 0.1237    ,
#           0.1237    , 0.14479999],
#          [0.3533    , 0.39249998, 0.39749998, ..., 0.0929    ,
#           0.1237    , 0.0894    ],
#          ...,
#          [0.1721    , 0.1743    , 0.1725    , ..., 0.175     ,
#           0.175     , 0.18959999],
#          [0.16659999, 0.15789999, 0.1665    , ..., 0.2417    ,
#           0.2417    , 0.2087    ],
#          [0.17459999, 0.163     , 0.1688    , ..., 0.1862    ,
#           0.21239999, 0.197     ]]], shape=(1, 203, 381), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2019-01-14
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 381)> Size: 309kB
#  array([[[0.6695    , 0.5051    , 0.55149996, ..., 0.1689    ,
#           0.1689    , 0.1678    ],
#          [0.48099998, 0.35529998, 0.55149996, ..., 0.1554    ,
#           0.1554    , 0.1554    ],
#          [0.4306    , 0.4782    , 0.35529998, ..., 0.14119999,
#           0.0697    , 0.0697    ],
#          ...,
#          [0.1753    , 0.16409999, 0.15959999, ..., 0.1612    ,
#           0.1612    , 0.1646    ],
#          [0.16589999, 0.15789999, 0.1627    , ..., 0.1779    ,
#           0.1779    , 0.1962    ],
#          [0.1563    , 0.15779999, 0.16569999, ..., 0.1372    ,
#           0.21509999, 0.21139999]]], shape=(1, 203, 381), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2019-01-16
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 381)> Size: 309kB
#  array([[[0.447     , 0.4718    , 0.4847    , ..., 0.16229999,
#           0.16229999, 0.1672    ],
#          [0.42909998, 0.32619998, 0.2836    , ..., 0.16229999,
#           0.16229999, 0.14729999],
#          [0.3807    , 0.45749998, 0.5017    , ..., 0.11369999,
#           0.11369999, 0.0657    ],
#          ...,
#          [0.1556    , 0.1577    , 0.15959999, ..., 0.1653    ,
#           0.1653    , 0.17549999],
#          [0.1556    , 0.1487    , 0.1581    , ..., 0.19559999,
#           0.19559999, 0.2083    ],
#          [0.1559    , 0.1487    , 0.15519999, ..., 0.1853    ,
#           0.1882    , 0.22209999]]], shape=(1, 203, 381), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2019-01-17
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 381)> Size: 309kB
#  array([[[0.2809    , 0.4193    , 0.4193    , ..., 0.1609    ,
#           0.1609    , 0.1691    ],
#          [0.302     , 0.3606    , 0.327     , ..., 0.10219999,
#           0.10219999, 0.1609    ],
#          [0.3922    , 0.39909998, 0.4491    , ..., 0.15079999,
#           0.10219999, 0.0633    ],
#          ...,
#          [0.161     , 0.15529999, 0.15779999, ..., 0.1689    ,
#           0.1689    , 0.2026    ],
#          [0.1581    , 0.14909999, 0.1589    , ..., 0.2049    ,
#           0.2049    , 0.2341    ],
#          [0.15689999, 0.1459    , 0.15689999, ..., 0.1538    ,
#           0.2402    , 0.2118    ]]], shape=(1, 203, 381), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2019-01-19
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 381)> Size: 309kB
#  array([[[0.3635    , 0.45319998, 0.6207    , ..., 0.1516    ,
#           0.1516    , 0.1516    ],
#          [0.33789998, 0.3635    , 0.4522    , ..., 0.16399999,
#           0.16399999, 0.1516    ],
#          [0.33789998, 0.4341    , 0.4341    , ..., 0.11      ,
#           0.11      , 0.0662    ],
#          ...,
#          [0.1768    , 0.1724    , 0.1722    , ..., 0.1691    ,
#           0.1691    , 0.1918    ],
#          [0.17469999, 0.17029999, 0.1655    , ..., 0.1691    ,
#           0.1691    , 0.19409999],
#          [0.1802    , 0.1692    , 0.1678    , ..., 0.19039999,
#           0.2403    , 0.2419    ]]], shape=(1, 203, 381), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2019-01-20
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 381)> Size: 309kB
#  array([[[0.32439998, 0.4516    , 0.50909996, ..., 0.1598    ,
#           0.1598    , 0.16309999],
#          [0.2705    , 0.3367    , 0.42909998, ..., 0.1336    ,
#           0.1336    , 0.14639999],
#          [0.43339998, 0.5049    , 0.3936    , ..., 0.1433    ,
#           0.0611    , 0.0611    ],
#          ...,
#          [0.1639    , 0.16      , 0.1656    , ..., 0.15259999,
#           0.15259999, 0.17289999],
#          [0.1598    , 0.15259999, 0.1617    , ..., 0.2173    ,
#           0.2173    , 0.2091    ],
#          [0.1601    , 0.1538    , 0.16149999, ..., 0.1661    ,
#           0.22929999, 0.2093    ]]], shape=(1, 203, 381), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2019-01-22
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 381)> Size: 309kB
#  array([[[0.4953    , 0.3929    , 0.5266    , ..., 0.1515    ,
#           0.1515    , 0.17      ],
#          [0.4635    , 0.3383    , 0.29369998, ..., 0.1488    ,
#           0.1488    , 0.12529999],
#          [0.4017    , 0.4768    , 0.4288    , ..., 0.1488    ,
#           0.1488    , 0.1191    ],
#          ...,
#          [0.1665    , 0.16569999, 0.16839999, ..., 0.1671    ,
#           0.1671    , 0.17629999],
#          [0.1583    , 0.1592    , 0.1603    , ..., 0.19739999,
#           0.19739999, 0.2034    ],
#          [0.16759999, 0.15709999, 0.1639    , ..., 0.1669    ,
#           0.2374    , 0.2356    ]]], shape=(1, 203, 381), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2019-01-24
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 381)> Size: 309kB
#  array([[[0.44259998, 0.5243    , 0.64849997, ..., 0.19739999,
#           0.19739999, 0.1779    ],
#          [0.63479996, 0.44259998, 0.4164    , ..., 0.1318    ,
#           0.1318    , 0.1717    ],
#          [0.3795    , 0.47379997, 0.4779    , ..., 0.1655    ,
#           0.1318    , 0.0982    ],
#          ...,
#          [0.1538    , 0.14549999, 0.1443    , ..., 0.1705    ,
#           0.1705    , 0.18419999],
#          [0.1478    , 0.137     , 0.1476    , ..., 0.2383    ,
#           0.2383    , 0.21409999],
#          [0.1441    , 0.14479999, 0.1485    , ..., 0.1978    ,
#           0.2126    , 0.199     ]]], shape=(1, 203, 381), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2020-01-14
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 381)> Size: 309kB
#  array([[[0.5825    , 0.42909998, 0.6479    , ..., 0.1899    ,
#           0.1899    , 0.1858    ],
#          [0.6619    , 0.4217    , 0.33339998, ..., 0.1538    ,
#           0.1538    , 0.1688    ],
#          [0.43159997, 0.44889998, 0.48709998, ..., 0.1134    ,
#           0.0685    , 0.0685    ],
#          ...,
#          [0.1533    , 0.14109999, 0.1415    , ..., 0.17029999,
#           0.17029999, 0.1777    ],
#          [0.14019999, 0.14109999, 0.14919999, ..., 0.2139    ,
#           0.2139    , 0.2341    ],
#          [0.14479999, 0.14019999, 0.1501    , ..., 0.1713    ,
#           0.22289999, 0.2341    ]]], shape=(1, 203, 381), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2020-01-16
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 381)> Size: 309kB
#  array([[[0.49899998, 0.51949996, 0.7036    , ..., 0.1793    ,
#           0.1793    , 0.1793    ],
#          [0.44829997, 0.3155    , 0.3956    , ..., 0.17359999,
#           0.17359999, 0.12459999],
#          [0.4168    , 0.4942    , 0.43609998, ..., 0.13859999,
#           0.1144    , 0.0784    ],
#          ...,
#          [0.1443    , 0.134     , 0.1449    , ..., 0.1556    ,
#           0.1556    , 0.176     ],
#          [0.1321    , 0.1318    , 0.14299999, ..., 0.22989999,
#           0.22989999, 0.2216    ],
#          [0.1388    , 0.1391    , 0.1481    , ..., 0.1971    ,
#           0.2355    , 0.2144    ]]], shape=(1, 203, 381), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2020-01-17
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 381)> Size: 309kB
#  array([[[0.2952    , 0.4438    , 0.44169998, ..., 0.1846    ,
#           0.1846    , 0.1687    ],
#          [0.3724    , 0.31399998, 0.3647    , ..., 0.1846    ,
#           0.1846    , 0.1687    ],
#          [0.3904    , 0.4883    , 0.44039997, ..., 0.14389999,
#           0.14389999, 0.0698    ],
#          ...,
#          [0.1427    , 0.1457    , 0.1454    , ..., 0.1793    ,
#           0.1793    , 0.18949999],
#          [0.13759999, 0.1428    , 0.1452    , ..., 0.2358    ,
#           0.2358    , 0.2482    ],
#          [0.1418    , 0.1433    , 0.14639999, ..., 0.2126    ,
#           0.22299999, 0.17999999]]], shape=(1, 203, 381), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2020-01-19
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 381)> Size: 309kB
#  array([[[0.2809    , 0.422     , 0.4398    , ..., 0.1558    ,
#           0.1558    , 0.1558    ],
#          [0.23959999, 0.35439998, 0.331     , ..., 0.1558    ,
#           0.1558    , 0.1558    ],
#          [0.4481    , 0.48639998, 0.4183    , ..., 0.1287    ,
#           0.0775    , 0.0775    ],
#          ...,
#          [0.1506    , 0.145     , 0.1405    , ..., 0.18079999,
#           0.18079999, 0.17889999],
#          [0.1387    , 0.1398    , 0.1466    , ..., 0.2554    ,
#           0.2554    , 0.2346    ],
#          [0.13849999, 0.1466    , 0.1502    , ..., 0.20729999,
#           0.2554    , 0.2349    ]]], shape=(1, 203, 381), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2020-01-20
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 381)> Size: 309kB
#  array([[[0.31509998, 0.43559998, 0.5191    , ..., 0.16749999,
#           0.16749999, 0.16749999],
#          [0.2823    , 0.3504    , 0.3304    , ..., 0.1056    ,
#           0.1056    , 0.1056    ],
#          [0.3978    , 0.4251    , 0.3759    , ..., 0.1549    ,
#           0.1056    , 0.1056    ],
#          ...,
#          [0.1433    , 0.1382    , 0.15339999, ..., 0.17899999,
#           0.17899999, 0.17899999],
#          [0.15869999, 0.15339999, 0.1585    , ..., 0.2085    ,
#           0.2085    , 0.2313    ],
#          [0.1619    , 0.1599    , 0.1647    , ..., 0.1568    ,
#           0.2342    , 0.2263    ]]], shape=(1, 203, 381), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2020-01-22
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 381)> Size: 309kB
#  array([[[0.27629998, 0.5169    , 0.5169    , ..., 0.1713    ,
#           0.1713    , 0.1697    ],
#          [0.3031    , 0.4021    , 0.3184    , ..., 0.1554    ,
#           0.1554    , 0.1219    ],
#          [0.3408    , 0.4626    , 0.4274    , ..., 0.1554    ,
#           0.1554    , 0.1219    ],
#          ...,
#          [0.1488    , 0.1425    , 0.146     , ..., 0.1669    ,
#           0.1669    , 0.1788    ],
#          [0.1422    , 0.14819999, 0.146     , ..., 0.2214    ,
#           0.2214    , 0.2286    ],
#          [0.1416    , 0.1519    , 0.14819999, ..., 0.17189999,
#           0.2261    , 0.2056    ]]], shape=(1, 203, 381), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2020-01-24
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 381)> Size: 309kB
#  array([[[0.51879996, 0.4226    , 0.593     , ..., 0.1442    ,
#           0.1442    , 0.1563    ],
#          [0.46269998, 0.3324    , 0.4215    , ..., 0.1236    ,
#           0.1236    , 0.1563    ],
#          [0.3391    , 0.4062    , 0.45009997, ..., 0.11499999,
#           0.1334    , 0.1236    ],
#          ...,
#          [0.11759999, 0.1169    , 0.11889999, ..., 0.1451    ,
#           0.1451    , 0.1586    ],
#          [0.1158    , 0.1166    , 0.11889999, ..., 0.2218    ,
#           0.2218    , 0.17889999],
#          [0.11539999, 0.1166    , 0.119     , ..., 0.1733    ,
#           0.2021    , 0.17889999]]], shape=(1, 203, 381), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2021-01-14
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 381)> Size: 309kB
#  array([[[0.5966    , 0.38709998, 0.534     , ..., 0.14209999,
#           0.14209999, 0.1431    ],
#          [0.4261    , 0.3412    , 0.3004    , ..., 0.144     ,
#           0.144     , 0.1215    ],
#          [0.36679998, 0.4111    , 0.347     , ..., 0.1416    ,
#           0.09559999, 0.0795    ],
#          ...,
#          [0.12419999, 0.125     , 0.125     , ..., 0.1555    ,
#           0.1555    , 0.16239999],
#          [0.1209    , 0.1264    , 0.125     , ..., 0.2004    ,
#           0.2004    , 0.1743    ],
#          [0.1209    , 0.1264    , 0.13059999, ..., 0.1749    ,
#           0.19309999, 0.1963    ]]], shape=(1, 203, 381), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2021-01-16
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 381)> Size: 309kB
#  array([[[0.5002    , 0.4511    , 0.4655    , ..., 0.1413    ,
#           0.1413    , 0.1457    ],
#          [0.3297    , 0.41279998, 0.3249    , ..., 0.14039999,
#           0.14039999, 0.1418    ],
#          [0.40989998, 0.33519998, 0.3166    , ..., 0.1545    ,
#           0.0976    , 0.0695    ],
#          ...,
#          [0.13499999, 0.1318    , 0.1487    , ..., 0.14999999,
#           0.14999999, 0.15269999],
#          [0.1308    , 0.1313    , 0.1312    , ..., 0.16679999,
#           0.16679999, 0.20089999],
#          [0.13      , 0.13      , 0.1355    , ..., 0.1498    ,
#           0.2174    , 0.18879999]]], shape=(1, 203, 381), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2021-01-17
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 381)> Size: 309kB
#  array([[[0.5255    , 0.32009998, 0.4583    , ..., 0.1687    ,
#           0.1687    , 0.16399999],
#          [0.5009    , 0.27699998, 0.20809999, ..., 0.154     ,
#           0.154     , 0.1545    ],
#          [0.4396    , 0.3066    , 0.26729998, ..., 0.147     ,
#           0.147     , 0.1063    ],
#          ...,
# ...
#    * date         (date) datetime64[ns] 8B 2023-01-22
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 381)> Size: 309kB
#  array([[[0.6608    , 0.4439    , 0.5297    , ..., 0.16849999,
#           0.16849999, 0.1525    ],
#          [0.3759    , 0.3442    , 0.3301    , ..., 0.1178    ,
#           0.1178    , 0.16849999],
#          [0.46429998, 0.35189998, 0.38099998, ..., 0.1647    ,
#           0.0909    , 0.1178    ],
#          ...,
#          [0.1435    , 0.14119999, 0.1468    , ..., 0.1787    ,
#           0.1787    , 0.1814    ],
#          [0.1423    , 0.138     , 0.1502    , ..., 0.20789999,
#           0.20789999, 0.22559999],
#          [0.14209999, 0.1372    , 0.15429999, ..., 0.1762    ,
#           0.20789999, 0.23089999]]], shape=(1, 203, 381), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2023-01-24
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 381)> Size: 309kB
#  array([[[0.61219996, 0.40179998, 0.5157    , ..., 0.20619999,
#           0.20619999, 0.1819    ],
#          [0.6793    , 0.3809    , 0.3254    , ..., 0.1519    ,
#           0.1519    , 0.1345    ],
#          [0.4533    , 0.51199996, 0.4612    , ..., 0.1481    ,
#           0.0762    , 0.0973    ],
#          ...,
#          [0.1673    , 0.16939999, 0.1723    , ..., 0.1529    ,
#           0.1529    , 0.1683    ],
#          [0.16129999, 0.1608    , 0.1749    , ..., 0.21      ,
#           0.21      , 0.2234    ],
#          [0.1696    , 0.1713    , 0.1801    , ..., 0.1883    ,
#           0.21239999, 0.2234    ]]], shape=(1, 203, 381), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2024-01-14
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 381)> Size: 309kB
#  array([[[0.4007    , 0.48      , 0.5675    , ..., 0.2094    ,
#           0.2094    , 0.1938    ],
#          [0.31599998, 0.3615    , 0.48      , ..., 0.1107    ,
#           0.1107    , 0.1107    ],
#          [0.4278    , 0.47079998, 0.3215    , ..., 0.1584    ,
#           0.11669999, 0.1107    ],
#          ...,
#          [0.17289999, 0.159     , 0.1642    , ..., 0.1786    ,
#           0.1786    , 0.175     ],
#          [0.16659999, 0.15959999, 0.1691    , ..., 0.233     ,
#           0.233     , 0.1874    ],
#          [0.1612    , 0.1752    , 0.175     , ..., 0.20099999,
#           0.20279999, 0.233     ]]], shape=(1, 203, 381), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2024-01-16
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 381)> Size: 309kB
#  array([[[0.7446    , 0.4692    , 0.629     , ..., 0.1865    ,
#           0.1865    , 0.1865    ],
#          [0.6199    , 0.4692    , 0.4547    , ..., 0.1131    ,
#           0.1131    , 0.1131    ],
#          [0.4608    , 0.48169997, 0.4563    , ..., 0.1636    ,
#           0.0733    , 0.1131    ],
#          ...,
#          [0.17799999, 0.16399999, 0.1727    , ..., 0.1661    ,
#           0.1661    , 0.1917    ],
#          [0.17189999, 0.1653    , 0.1821    , ..., 0.2095    ,
#           0.2095    , 0.1828    ],
#          [0.1696    , 0.1699    , 0.184     , ..., 0.17189999,
#           0.2101    , 0.25509998]]], shape=(1, 203, 381), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2024-01-17
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 381)> Size: 309kB
#  array([[[0.4687    , 0.4391    , 0.3651    , ..., 0.1819    ,
#           0.1819    , 0.17459999],
#          [0.4687    , 0.4687    , 0.3375    , ..., 0.1819    ,
#           0.1819    , 0.1802    ],
#          [0.3734    , 0.3734    , 0.40179998, ..., 0.14299999,
#           0.14299999, 0.1164    ],
#          ...,
#          [0.1697    , 0.16679999, 0.17369999, ..., 0.16579999,
#           0.16579999, 0.1845    ],
#          [0.1612    , 0.16659999, 0.1802    , ..., 0.1704    ,
#           0.1704    , 0.2224    ],
#          [0.17189999, 0.17029999, 0.17819999, ..., 0.1361    ,
#           0.21239999, 0.2314    ]]], shape=(1, 203, 381), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2024-01-19
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 381)> Size: 309kB
#  array([[[0.6572    , 0.4508    , 0.4508    , ..., 0.191     ,
#           0.191     , 0.1902    ],
#          [0.72179997, 0.48709998, 0.34849998, ..., 0.1055    ,
#           0.1055    , 0.1902    ],
#          [0.366     , 0.4597    , 0.4775    , ..., 0.1803    ,
#           0.1055    , 0.1055    ],
#          ...,
#          [0.15789999, 0.1573    , 0.16129999, ..., 0.1741    ,
#           0.1741    , 0.18339999],
#          [0.1577    , 0.1525    , 0.1697    , ..., 0.2039    ,
#           0.2039    , 0.25419998],
#          [0.1572    , 0.1577    , 0.176     , ..., 0.1662    ,
#           0.22989999, 0.22199999]]], shape=(1, 203, 381), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2024-01-20
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 381)> Size: 309kB
#  array([[[0.5266    , 0.4459    , 0.5485    , ..., 0.1854    ,
#           0.1854    , 0.1854    ],
#          [0.59389997, 0.3204    , 0.29889998, ..., 0.1854    ,
#           0.1854    , 0.1854    ],
#          [0.43249997, 0.48389998, 0.48389998, ..., 0.1776    ,
#           0.119     , 0.119     ],
#          ...,
#          [0.1576    , 0.1511    , 0.1513    , ..., 0.17289999,
#           0.17289999, 0.19309999],
#          [0.1556    , 0.1546    , 0.1647    , ..., 0.2288    ,
#           0.2288    , 0.2538    ],
#          [0.1551    , 0.1644    , 0.1731    , ..., 0.2085    ,
#           0.2386    , 0.22739999]]], shape=(1, 203, 381), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2024-01-22
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 381)> Size: 309kB
#  array([[[0.5933    , 0.45009997, 0.561     , ..., 0.1683    ,
#           0.1683    , 0.1766    ],
#          [0.4585    , 0.45009997, 0.4096    , ..., 0.13939999,
#           0.13939999, 0.16319999],
#          [0.4585    , 0.4553    , 0.4156    , ..., 0.13239999,
#           0.0678    , 0.0917    ],
#          ...,
#          [0.1583    , 0.14999999, 0.15789999, ..., 0.18519999,
#           0.18519999, 0.1832    ],
#          [0.1547    , 0.14999999, 0.15869999, ..., 0.2144    ,
#           0.2144    , 0.23519999],
#          [0.1494    , 0.1611    , 0.1611    , ..., 0.18959999,
#           0.2144    , 0.2191    ]]], shape=(1, 203, 381), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2024-01-24
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 381)> Size: 309kB
#  array([[[0.4254    , 0.445     , 0.565     , ..., 0.15869999,
#           0.15869999, 0.1486    ],
#          [0.31509998, 0.4254    , 0.565     , ..., 0.161     ,
#           0.161     , 0.1486    ],
#          [0.4129    , 0.3478    , 0.2938    , ..., 0.1209    ,
#           0.12419999, 0.0818    ],
#          ...,
#          [0.1232    , 0.1252    , 0.13239999, ..., 0.15689999,
#           0.15689999, 0.1514    ],
#          [0.12249999, 0.12629999, 0.1338    , ..., 0.19849999,
#           0.19849999, 0.1863    ],
#          [0.1259    , 0.12979999, 0.1326    , ..., 0.1714    ,
#           0.2004    , 0.16239999]]], shape=(1, 203, 381), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2025-01-14
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 381)> Size: 309kB
#  array([[[0.4488    , 0.5611    , 0.58349997, ..., 0.1494    ,
#           0.1494    , 0.13679999],
#          [0.3665    , 0.3071    , 0.2633    , ..., 0.1451    ,
#           0.1451    , 0.1162    ],
#          [0.378     , 0.44829997, 0.33449998, ..., 0.1296    ,
#           0.0588    , 0.0588    ],
#          ...,
#          [0.1287    , 0.1304    , 0.129     , ..., 0.147     ,
#           0.147     , 0.14379999],
#          [0.1187    , 0.1312    , 0.13069999, ..., 0.197     ,
#           0.197     , 0.19039999],
#          [0.1187    , 0.1312    , 0.1322    , ..., 0.15709999,
#           0.1847    , 0.1827    ]]], shape=(1, 203, 381), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2025-01-16
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 381)> Size: 309kB
#  array([[[0.3674    , 0.43949997, 0.44439998, ..., 0.14209999,
#           0.14209999, 0.14209999],
#          [0.5428    , 0.3004    , 0.3277    , ..., 0.1523    ,
#           0.1523    , 0.1318    ],
#          [0.3489    , 0.45749998, 0.4396    , ..., 0.1302    ,
#           0.0949    , 0.1318    ],
#          ...,
#          [0.12799999, 0.1223    , 0.1251    , ..., 0.17029999,
#           0.17029999, 0.1453    ],
#          [0.1219    , 0.1223    , 0.12879999, ..., 0.22129999,
#           0.22129999, 0.161     ],
#          [0.1243    , 0.1283    , 0.1318    , ..., 0.1689    ,
#           0.2329    , 0.20439999]]], shape=(1, 203, 381), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2025-01-17
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 381)> Size: 309kB
#  array([[[0.6297    , 0.44529998, 0.3931    , ..., 0.14109999,
#           0.14109999, 0.1305    ],
#          [0.5032    , 0.44529998, 0.3931    , ..., 0.1321    ,
#           0.1321    , 0.1142    ],
#          [0.43809998, 0.319     , 0.3279    , ..., 0.1564    ,
#           0.0924    , 0.0563    ],
#          ...,
#          [0.1313    , 0.1344    , 0.1308    , ..., 0.1434    ,
#           0.1434    , 0.15609999],
#          [0.1283    , 0.1326    , 0.137     , ..., 0.2183    ,
#           0.2183    , 0.2013    ],
#          [0.1258    , 0.1239    , 0.1374    , ..., 0.17549999,
#           0.2047    , 0.1633    ]]], shape=(1, 203, 381), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2025-01-19
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 381)> Size: 309kB
#  array([[[0.6709    , 0.4362    , 0.4377    , ..., 0.1407    ,
#           0.1407    , 0.1328    ],
#          [0.6709    , 0.4068    , 0.3769    , ..., 0.1334    ,
#           0.1334    , 0.1292    ],
#          [0.35909998, 0.34829998, 0.3988    , ..., 0.1314    ,
#           0.0579    , 0.0818    ],
#          ...,
#          [0.12019999, 0.125     , 0.1245    , ..., 0.1494    ,
#           0.1494    , 0.15359999],
#          [0.13149999, 0.1213    , 0.1256    , ..., 0.1494    ,
#           0.1494    , 0.1698    ],
#          [0.1209    , 0.129     , 0.1305    , ..., 0.16929999,
#           0.20369999, 0.23529999]]], shape=(1, 203, 381), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2025-01-20
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 381)> Size: 309kB
#  array([[[0.4236    , 0.37649998, 0.48299998, ..., 0.1434    ,
#           0.1434    , 0.1337    ],
#          [0.302     , 0.44739997, 0.354     , ..., 0.16679999,
#           0.16679999, 0.1639    ],
#          [0.38819999, 0.3714    , 0.3284    , ..., 0.1187    ,
#           0.11189999, 0.0708    ],
#          ...,
#          [0.1274    , 0.12199999, 0.1256    , ..., 0.1619    ,
#           0.1619    , 0.1485    ],
#          [0.123     , 0.1223    , 0.1276    , ..., 0.2197    ,
#           0.2197    , 0.1821    ],
#          [0.12379999, 0.1245    , 0.1308    , ..., 0.1609    ,
#           0.2197    , 0.18439999]]], shape=(1, 203, 381), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2025-01-22
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area,
#  <xarray.DataArray 'NDVI' (date: 1, y: 203, x: 381)> Size: 309kB
#  array([[[0.6246    , 0.4477    , 0.67539996, ..., 0.127     ,
#           0.127     , 0.127     ],
#          [0.6932    , 0.42749998, 0.3254    , ..., 0.1188    ,
#           0.1188    , 0.1188    ],
#          [0.36699998, 0.47669998, 0.4089    , ..., 0.1375    ,
#           0.0731    , 0.0462    ],
#          ...,
#          [0.1213    , 0.11279999, 0.1192    , ..., 0.139     ,
#           0.139     , 0.1382    ],
#          [0.1139    , 0.11149999, 0.1244    , ..., 0.139     ,
#           0.139     , 0.15179999],
#          [0.1152    , 0.13329999, 0.1302    , ..., 0.16129999,
#           0.2091    , 0.2038    ]]], shape=(1, 203, 381), dtype=float32)
#  Coordinates:
#      band         int64 8B 1
#    * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#    * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#      spatial_ref  int64 8B 0
#    * date         (date) datetime64[ns] 8B 2025-01-24
#  Attributes:
#      units:          NDVI
#      AREA_OR_POINT:  Area]

# %% [markdown]
# <link rel="stylesheet" type="text/css" href="./assets/styles.css"><div class="callout callout-style-default callout-titled callout-task"><div class="callout-header"><div class="callout-icon-container"><i class="callout-icon"></i></div><div class="callout-title-container flex-fill">Try It</div></div><div class="callout-body-container callout-body"><p>Next, stack your arrays by date into a time series:</p>
# <ol type="1">
# <li>Modify the code to match your prior workflow steps and to use
# descriptive variable names</li>
# <li>Replace <code>coordinate_name</code> with the actual name of the
# coordinate you want to build up.</li>
# </ol></div></div>

# %%
# Combine NDVI images from all dates
ndvi_da_dl = xr.combine_by_coords(ndvi_das_dl, coords=['date'])
ndvi_da_dl
# Out:
# /tmp/ipykernel_9384/2552760617.py:2: FutureWarning: In a future version of xarray the default value for compat will change from compat='no_conflicts' to compat='override'. This is likely to lead to different results when combining overlapping variables with the same name. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set compat explicitly.
#   ndvi_da_dl = xr.combine_by_coords(ndvi_das_dl, coords=['date'])
# /tmp/ipykernel_9384/2552760617.py:2: FutureWarning: In a future version of xarray the default value for compat will change from compat='no_conflicts' to compat='override'. This is likely to lead to different results when combining overlapping variables with the same name. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set compat explicitly.
#   ndvi_da_dl = xr.combine_by_coords(ndvi_das_dl, coords=['date'])
# <xarray.Dataset> Size: 24MB
# Dimensions:      (date: 77, y: 203, x: 381)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 3kB -112.3 -112.3 -112.3 ... -111.5 -111.5 -111.5
#   * y            (y) float64 2kB 33.39 33.39 33.38 33.38 ... 32.97 32.97 32.97
#     spatial_ref  int64 8B 0
#   * date         (date) datetime64[ns] 616B 2015-01-14 2015-01-16 ... 2025-01-24
# Data variables:
#     NDVI         (date, y, x) float32 24MB 0.5246 0.4913 ... 0.2091 0.2038

# %%
len(ndvi_da)
# Out:
# 1

# %%
# Calculate difference in NDVI (After water rights are restored - Before)
ndvi_diff = (
    ndvi_da
        .sel(date=slice('2020', '2025'))
        .mean('date')
        .NDVI 
   - ndvi_da
        .sel(date=slice('2015', '2020'))
        .mean('date')
        .NDVI
)
print(ndvi_diff.head())

ndvi_diff_plot = (
    ndvi_diff.hvplot(x='x', y='y', cmap='PiYG', geo=True, title='NDVI difference: 2012-2022 minus 2001-2012')
    *
    gila_boundary.hvplot(geo=True, fill_color=None, line_color='black')
)

ndvi_diff_plot
# Out:
# <xarray.DataArray 'NDVI' (y: 5, x: 5)> Size: 100B
# array([[-4.8951507e-03, -6.3167810e-03, -2.7409554e-02, -5.1002413e-02,
#         -1.7824054e-01],
#        [-8.9520216e-04,  2.0159543e-02,  2.6952922e-03, -3.5369068e-02,
#         -3.5369068e-02],
#        [ 8.3642900e-03,  1.7938077e-02,  2.0280898e-02,  2.3752451e-05,
#          2.3752451e-05],
#        [ 1.2476176e-02,  1.0966629e-02, -5.2142143e-04, -5.2142143e-04,
#         -5.4786801e-03],
#        [-2.5130957e-02, -2.9857159e-03, -1.0752410e-02, -1.0752410e-02,
#         -9.1214180e-03]], dtype=float32)
# Coordinates:
#     band         int64 8B 1
#   * x            (x) float64 40B -112.3 -112.3 -112.3 -112.3 -112.3
#   * y            (y) float64 40B 33.39 33.39 33.38 33.38 33.38
#     spatial_ref  int64 8B 0
# :Overlay
#    .Image.I    :Image   [x,y]   (NDVI)
#    .Polygons.I :Polygons   [Longitude,Latitude]

# %%
# Save plot as html for easy sharing
hv.save(ndvi_diff_plot, "gila_ndvi_diff_plot.html")
# Out:
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: figure(id='p1365', ...)

# %% [markdown]
# # STEP -1: Wrap up
#
# Don’t forget to store your variables so you can use them in other
# notebooks! Replace `var1` and `var2` with the variable you want to save,
# separated by spaces.

# %%
# %store ndvi_diff
# Out:
# Stored 'ndvi_diff' (DataArray)

# %% [markdown]
# Finally, be sure to `Restart` and `Run all` to make sure your notebook
# works all the way through!
